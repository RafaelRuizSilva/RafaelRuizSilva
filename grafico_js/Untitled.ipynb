# %%
import pandas as pd

# %%
df_adesao = pd.read_excel('base_adesao_colabs.xlsx', engine='openpyxl')

# %%
df_adesao.to_csv('adesao_colabs.csv', index=False)

# %%
df_adesao
# Out:
#                 COLABORADOR SUPERVISOR  QTD Pontos preencheidos  \
# 0      JOSE ALFREDO CAMARGO   LEANDRO                        10
# 1            MARINA CLEIDSA   LEANDRO                        25
# 2              JONAS CAMILO   LEANDRO                        30
# 3             MARCEL COELHO   LEANDRO                         2
# 4      RAFAEL RUIZ DA SILVA  BERNADINO                        5
# 5   GUILHERME RUIZ DA SILVA  BERNADINO                        8
# 6          BRUNO NASCIMENTO  BERNADINO                        8
# 7            ISAC DE VIETRO  BERNADINO                       15
# 8                HIGOR DIAS        ANA                       18
# 9                    NALDO         ANA                       27
# 10                   ALEZIN        ANA                       30
#
#     QTD Pontos totais  PERCENTUAL_ADESAO  total_adesao  qtd_colabs_total  \
# 0                  30          33.333333            80                32
# ...

# %%
adesao_html = df_adesao.to_html(border=0)

# %%
print(adesao_html)
# Out:
# <table border="0" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>COLABORADOR</th>
#       <th>SUPERVISOR</th>
#       <th>QTD Pontos preencheidos</th>
#       <th>QTD Pontos totais</th>
#       <th>PERCENTUAL_ADESAO</th>
#       <th>total_adesao</th>
#       <th>qtd_colabs_total</th>
#       <th>qtd_colabs_ativos</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>JOSE ALFREDO CAMARGO</td>
#       <td>LEANDRO</td>
#       <td>10</td>
#       <td>30</td>
#       <td>33.333333</td>
#       <td>80</td>
#       <td>32</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>MARINA CLEIDSA</td>
#       <td>LEANDRO</td>
#       <td>25</td>
#       <td>30</td>
#       <td>83.333333</td>
#       <td>80</td>
#       <td>32</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>JONAS CAMILO</td>
#       <td>LEANDRO</td>
#       <td>30</td>
#       <td>30</td>
# ...

# %%
#text_file = open("tabela_dropdown.html", "w")
#text_file.write(adesao_html)
#text_file.close()
